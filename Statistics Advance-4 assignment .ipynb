# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.

# %% [markdown]
# - Z - Test used to test Null Hypothesis if the population variance is known and the sample size is grater than 30.
#
# * T - Test used if the population variance is unknown and sample size is less than 30.

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests.

# %% [markdown]
# One - tailed test will have only one critical region.
#
# two - tailed test will have two critical region.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.

# %% [markdown]
# Type 1 Error -- The test result says you committed a crime but in reality you didn't.
#
# Type 2 Error -- The test result says you didn't committed a crime but in reality you did.

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.

# %% [markdown]
# Example -- there is a test for liver disease, which is different from actually having the liver disease, i.e. an event. Rare events might be having a higher false positive rate.

# %% [markdown]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

# %% [markdown]
# A range of values that describes the uncertainty surrounding an estimate.

# %% [markdown]
# Let we have
#
# STD = 100
#
# n = 25
#
# x bar(sample mean) = 520
#
# Critical value = 0.95
#
# alfa = 0.05

# %% [markdown]
# FORMULA = (X BAR) +- Z(alfa/2) * STD/root(n)

# %% [markdown]
# 520 +- 1.96 * 100/root(25)
#
# Lower Confidence interval = 480.8
#
# Higher Confidence interval = 559.2

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.

# %% [markdown]
# Bayes' Theorem states that the conditional probability of an event, based on the occurrence of another event, is equal to the likelihood of the second event given the first event multiplied by the probability of the first event.

# %% [markdown]
# EXAMPLE =
#
# Size of house = x1
#
# No. of rooms = x2
#
# Location = x3
#
# price = y

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 13.39.11.jpeg](attachment:0ed0096d-3a04-486f-a1bb-5682382a42ef.jpeg)

# %% [markdown]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.

# %% [markdown]
# ![WhatsApp Image 2023-04-24 at 17.38.08.jpeg](attachment:2cf8f647-27c3-40c0-bdfd-e11fd1d2dbac.jpeg)

# %% [markdown]
# Let n = 50

# %% [markdown]
# LOWER C.I = 50 - 1.385929113
#
# 48.614070887

# %% [markdown]
# HIGHER C.I = 50 + 1.385929113
#
# 51.385929113

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.

# %% [markdown]
# z-score = (data point - population mean) / population standard deviation
#
# z-score = (75 - 70) / 5
#
# z-score = 1

# %% [markdown]
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.

# %% [markdown]
# The margin of error is half the confidence interval.

# %% [markdown]
# the larger the sample size, the smaller the sample standard error and therefore the smaller the margin of error.

# %% [markdown]
# EXAMPLE = on the verbal section of cat exam the standard deviation is 100 . a sample of 50 test takes has a mean 520 contruct a 95 % C.I about the mean ?

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 13.59.34.jpeg](attachment:492a3c28-2750-4f93-8f52-fd5bc5f10050.jpeg)

# %% [markdown]
# LOWER C.I = 492.28
#
# HIGHER C.I = 547.71

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.

# %% [markdown]
# n = 50
#
# sample mean = 6
#
# sample std = 2.5
#
# Critical value = 2.0096

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 14.19.37.jpeg](attachment:280b2b2e-3099-4aa0-b393-705a1aeb13b3.jpeg)

# %% [markdown]
# LOWER C.I = 1.65
#
# HIGHER C.I = 2.36

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.

# %% [markdown]
# 500 people in jobs
#
# 325 people being satisfied with their current job.
#
# 175 people not satisfied with their current job.
#
# according to this survey

# %% [markdown]
# Let sample mean = 325

# %% [markdown]
# Sample std = 113.75

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 14.36.32.jpeg](attachment:8d70853c-d5fd-4804-aa65-1c11b64a5ef0.jpeg)

# %% [markdown]
# LOWER C.I = 315.0
#
# HIGHER C.I = 334.9

# %% [markdown]
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.

# %% [markdown]
# FOR Teaching method (A)
#
# - sample mean = 85
# - sample std = 6
#
# FOR Teaching method (B)
#
# - sample mean = 82
# - sample std = 5

# %% [markdown]
# NULL HYPOTHESIS (Ho) = Teaching method A > Teaching method B
#
# ALTERNATIVE HYPOTHESIS (H.) = Teaching method A < Teaching method B

# %% [markdown]
# For A and B
#
# critical value = 2.57

# %% [markdown]
# T - test = (x̄1 - x̄2) / sqrt(s1^2/n1 + s2^2/n2)
#
# = 8.06

# %% [markdown]
# T test is greater than critical value

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.

# %% [markdown]
# Population mean = 60
#
# population std = 8
#
# Sample Data
#
# - n = 50
# - sample mean = 65
#
# C.I = 90 %
#
# ALFA = 5 %

# %% [markdown]
# Critical value = 1.64 (approximately)

# %% [markdown]
# confidence interval Using z - test formula :

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 15.43.37.jpeg](attachment:b87d6215-73bc-4e11-ae61-49f2c5059016.jpeg)

# %% [markdown]
# LOWER C.I = 63.14
#
# HIGHER C.I = 66.85

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [markdown]
# SAMPLE DATA :
#
# - n = 30
# - sample mean = 0.25 seconds
# - sample std = 0.05

# %% [markdown]
# NULL HYPOTHESIS (Ho) = average reaction time = 0.25
#
# ALTERNATIVE HYPOTHESIS (H.) = average reaction time __NOT EQUAL__ 0.25

# %% [markdown]
# Critical value = 1.699

# %% [markdown]
# ![WhatsApp Image 2023-04-25 at 16.20.54.jpeg](attachment:42a189d3-7987-4403-b2c3-3a862e2a593a.jpeg)

# %% [markdown]
# LOWER C.I = 0.23
#
# HIGHER C.I = 0.26
